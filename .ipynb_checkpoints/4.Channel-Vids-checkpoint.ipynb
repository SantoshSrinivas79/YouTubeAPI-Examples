# %% [markdown]
# # YouTube Data API (Get all videos of a channel)
#
# ![](https://lh3.googleusercontent.com/j2SJC1grxLdL94kX7uB9WclD_nqX49oJs3K82Tok1MaPcx4TvB2m7xmw-Ub4dvFORwPSzruQBWePxtizfuY1r3j4GQvi1G9z=s688)
#
# [console.developers.google.com](https://console.developers.google.com/cloud-resource-manager)

# %%
api_key = "!@#@!#@!#@!#@!"
# check password repo!

# %%
# pip install --upgrade google-api-python-client oauth2client
# pip install --upgrade google-api-python-client

# pip install uritemplate.py


# credit: https://stackoverflow.com/a/30811628/644081
from googleapiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_videos(channel_id):
    
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
# videos = get_channel_videos('UCkUq-s6z57uJFUFBvZIVTyg')
videos = get_channel_videos('UCn3bV5kx77HsVwtnlCeEi_A')

# %%
len(videos)
# Out:
# 318

# %%
for video in videos:
    print(video['snippet']['title'])
# Out:
# Configuring ERPNext - Domain Settings, Global Defaults & Print Settings
# Print Settings and Configuration in ERPNext
# The Architecture of ERPNext (for Beginners): Founder Series - Ep 3
# Users, Roles and Permissions - Managing your users in ERPNext
# Importing Data In ERPNext
# The Truth About ERP Implementations: Founder Series Ep 2
# Origins of ERPNext: Founder Series Ep 1
# Customizing DocTypes - Customizing ERP Modules in ERPNext
# Understanding DocTypes and Field Types
# Frappe Cloud for Dedicated Hosting of ERPNext and Frappe Apps - Webinar Recording
# Chester Lai from iTell Asia on ERPNext SaaS Sales - Webinar for ERPNext Partners
# Rushabh Mehta: Business of Open Source - IIM Bangalore - NSRCEL
# CA Liyakat Lal - Experience as ERPNext Partner
# ERPNext Story at Seibert Media
# What CTO of Zerodha thinks of ERPNext?
# Why ERPNext? - An introduction to the Community-Driven Open Source ERP Software
# Getting Started with ERPNext - ERP tutorial
# Introducing ERPNext AI
# ERPNext  - User Permissions - Webinar
# ERPNext - Users and Roles - Webinar
# ERPNext - Credit / Debit Note Allocation via JV - Webinar
# ERPNext - Credit / Debit Note Allocation - Webinar
# ERPNext - Improved Data Import (Beta) - Webinar
# ERPNext - Warehouses with Racks and Bins - Webinar
# ERPNext - Customer, Address and Contact
# ERPNext - Item Master - Webinar
# ERPNext - Price List and Item Price - Webinar
# ERPNext - Multi Company Setup - Webinar Recording
# Interview with Deepak Ingle (Reliance Industries)
# Dilpreet Kaur - Consulting ERPNext
# ERPNext story at Vedmata Gayatri Trust
# Antonius Tara - My ERPNext Mission
# Rushabh Mehta - What's next for Frappe
# Smital and Salman -  Challenges in Enterprise Sales
# Liyakat Lal - CA's perspective of ERPNext Accounts module
# Ashutosh Nadkarni - Bringing success to projects
# Ketan and Rushikesh - ERPNext Partner Program
# Basawaraj Savalagi - Can ERPNext disrupt Enterprise
# Umair Sayed - ERPNext Version 12
# Ajit and Himanshu - Scaling in 60 seconds
# Sneha and Vishal - Reporting for Scale
# Umair and Rohit - Managing support for ERPNext
# Nabin Hait - ERPNext Release Process
# Prashant Soni - ERPNext implementation at AWGP
# Himanshu and Abhishek - Kafka for Background Jobs
# Nikhil Sharma - Open Source and Enterprises
# Rucha Mahabal - Event Streaming in ERPNext
# Satish Annigeri - Role of FOSS in higher education
# Aditya Hase - Dynamic Scaling with ERPNext
# Jai Chavan - Demystifying ERP implementations
# Prasad Ramesh - Documenting ERPNext
# Rushabh Mehta - Do We Need Managers?
# Richa Verma - Choosing the right ERP solution for SMBs
# Seibert Media - Journey with ERPNext
# Kailash Nadh - Thoughts on FOSS and "Enterprise"
# ERPNext - Item Tax Template and Tax Category in version 12
# ERPNext - Chart of Accounts Importer in Version 12
# ERPNext -  Custom Accounting Dimensions in Version 12
# ERPNext - New Dashboard in Version 12
# Revisiting ERPNext Conference 2018
# Umair - User Documentation Contribution Sprint
# Nabin - Why to Contribute, Challenges and how to overcome them
# Rushabh - Vision of ERPNext and how we performed in the last year
# Dominik - Eso-Electironics Open Hardware, with ERPNext Integration
# Elastic Run - Development of features like federated model, single sign-on feartures in ERPNext
# Gaurav - MN Technique - ERPNext Vanilla Implementation and Driving Contribution
# Kanhiya Kale - New Indictrans - Contribution Challenges and How to Overcome It
# Pawan - OpenEtech - Best practices for Implementation & how contribution helps
# Rajarajan - Optimizing the UI capabilities of Frappe and ERPNext to create website and dashboards
# Zerodha - Vinay on Implementating ERPNext for the Largest Share Broking Firm of India
# Sachin Mane - ERPNext implementation at Elastic Run. Future of ERPNext as a federated system
# Dhananjay Palshikar - ERPNext Implementation at Sapcon, a measuring instruments manufacturer
# Rushabh Mehta - Future Role of Frappe Technology in ERPNext Eco-system
# Umair Sayed - Frappe Technologies as a Service Provider
# Faris Ansari - Frappe Accounting
# Prateeksha Singh - New Frappé Features and Marketplace
# Shivam Mishra - Frappé Academy Demo Sneak Peek
# Suraj Shetty - Version 12 Sneak Peeks, Postgres Support and Social
# Aditya Hase - Building ERPNext Connectors for other Accounting Apps like Tally and Quickbooks
# ERPNext Conference 2018 - Day 4
# [LIVE] ERPNext Conference 2018 - Day 3
# ERPNext Conference 2018 - Memories Trailer
# ERPNext Version 11: Discussion with Developers
# ERPNext - Education - Webinar
# ERPNext - HUB Market - Webinar
# ERPNext - User Permissions Updates in V11 - Webinar
# ERPNext - Timer in Timesheet - V11 Webinar
# ERPNext  - Standalone Debit and Credit Note - V11 Webinar
# ERPNext  - Auto Repeat - V11 Webinar
# ERPNext - Asset Movement - V11 Webinar
# ERPNext - Asset CWIP - Webinar
# ERPNext - DataTable - Webinar
# HR Module - ERPNext V11.0 - Webinar Recording
# Payroll - ERPNext V11.0 - Webinar Recording
# Deferred Revenue - ERPNext V11.0 - Webinar recording
# Employee Promotion and Transfer - ERPNext V 11.0 - Webinar Recording
# Leave Management - ERPNext V 11.0 -  Webinar Recording
# ERPNext - Shift Management - Webinar Recording
# ERPNext - Staffing Plan - Webinar Recording
# ERPNext - Onboarding & Separation - Webinar Recoding
# ERPNext - Attendance Request - Webinar Recording
# ERPNext - Subcontracting Enhancements - Webinar Recording
# ERPNext - Shareholders Management - Webinar Recording
# ERPNext - Quality Inspection Enhancements - Webinar Recoding
# ERPNext - Version 11 Upgrades - Webinar Recoding 1.1
# ERPNext - BOM Item Alternative - Webinar Recording
# ERPNext - Serialized Inventory Management
# ERPNext - Opening Invoice Creation Tool
# ERPNext - Product Bundle
# ERPNext - Pricing Rule
# ERPNext - Applying Discounts
# ERPNext - ESOC Desktop Module
# ERPNext - FrappeJS - REST API and ORM
# ERPNext - FrappeJS - Child and Single DocType
# ERPNext - Frappe JS DocTypes - ESoC 2018
# ERPNext - Frappe JS Setup - ESoC 2018
# ERPNext - Email Inbox
# ERPNext - Email Account Setup
# ERPNext Summer of Code 2018 - Introductory Call
# ERPNext - Advance Payment Entry
# ERPNext - Subscription Management
# ERPNext - Employee Advance Management
# ERPNext Non-Profits - Grants Management
# ERPNext Non-Profits - Memberships
# ERPNext Non-Profit - Member & Membership Types
# ERPNext Non-Profit - Donor
# ERPNext NGO - Volunteer
# ERPNext - Payment Terms
# ERPNext - Non-profit Domain
# ERPNext Version 10 features: A/C Numbering, Tree view for Task & Employee
# ERPNext - Creating Multiple Item Variants
# ERPNext - Data Import (Updated)
# ERPNext for Agriculture, Farmers
# ERPNext - VAT for UAE and KSA
# ERPNext Education - Fee and Payment
# ERPNext Education - Fee Schedule
# ERPNext Education - Student Attendance
# ERPNext Education - Student Leave Application
# ERPNext Schools - Assessment Result and Assessment Result Tool
# ERPNext Schools - Assessment Group
# ERPNext School - Assessment Criteria and Grading
# ERPNext School - Assessment Plan
# ERPNext Schools - Course Scheduling
# ERPNext School - Fee Structure
# ERPNext Schools - Student Groups
# ERPNext School - Instructor
# Eric Delisle - Extending ERPNext Website + E-commerce
# Data Migration Tool in Frappe Framework, by Faris & Prateeksha
# Kanchan Chauhan - ERPNext Implementation at Eso Electronic
# Faris Ansari - Frappe UI, Creating Dashboard and Reports
# Nabin Hait - Contribution Guidelines
# Prateeksha Singh - Frappe Controls,  Barcode Controller
# Rushabh - Frappe Portal, Website + Web Forms + E-commerce
# Rushabh Mehta - Better Together, ERPNext Monolith, Open Source History
# Achilles Rasquinha -  Frappe Framework Vs Django Vs Meteor
# Saurabh Palande - Servers Management at Frappe Technologies
# Ameya Shenoy - Frappe Bench Manager
# Rushabh Mehta - ERPNext Hub and ERPNext Desktop
# Aravind Govindaraj - Migrating to ERPNext from Tally
# Sarita Mulye - Implementing ERPNext Schools at Shishuvan
# Manish Jain - Integrating ERPNext with the Cloud Telephony System
# Gupteshwar Joshi - Customization to Generic Feature Development
# Gaurav Naik - Frappe Webhooks and more
# Alain Berger - ERPNext for Agriculture
# Anoop Kurungadam - Contributing Healthcare Domain in ERPNext
# Rushabh Mehta - ERPNext Foundation
# ERPNext School - Program Enrollment
# ERPNext Reseller Program
# ERPNext - Tasks and Timesheets
# ERPNext - Project Management
# ERPNext Schools - Students Management
# ERPNext Schools - Program and Courses
# ERPNext - Renaming Masters
# ERPNext - Edit Submitted Document (Cancel and Amend)
# ERPNext - Production Order (Material Transfer, Timesheet, Manufacture Entry)
# ERPNext - Manufacturing Operations & Workstations
# ERPNext - Production Planning Tool
# ERPNext - Bill of Materials (BOM)
# ERPNext - Tree master (Chart of Accounts, Warehouse, Item Group)
# ERPNext - Purchase Cycle (Purchase Order, Purchase Receipt, Purchase Invoice, Payment)
# ERPNext - Sales Cycle (Sales Order - Delivery Note - Sales Invoice - Payment)
# ERPNext - Material Request
# ERPNext - Student Application
# ERPNext - GST (Goods and Services Tax) feature for India
# ERPNext - Website Module
# How to Contribute to ERPNext
# ERPNext Version 8 (Beta) - Email Inbox, POS, Multiple UoM in sales, Student Assessment
# Nabin Hait - ERPNext Version 8 features
# Rushabh Mehta - Frappe Foundation, winning as a community
# Wolfram Schmidt - ERPNext for Incident based Project and Billing
# Alfred Marx - Custom Application on Frappe
# Robert Becht - Implementing ERPNext for the World Bank project
# Stavros Anastasiadis - ERPNext vs Django
# Antonious Tara - Implementing ERPNext for Import Business
# Dominik Ottenbreit - ERPNext Implementation at ESO Electronics, Germany
# Rushabh Mehta - Frappe Framework
# ERPnext Europe Conference 2017 - Welcome by Dominik
# ERPNext - Employee Loan Management
# ERPNext - Naming Series
# ERPNext - Custom Report Builder
# ERPNext  - Accounts module
# ERPNext - Employees
# Frappe - Creating a Custom Application & Integrating it with ERPNext
# ERPNext - User and Permissions
# ERPNext - Make to Order & Make to Stock
# ERPNext version 8 (beta) - Kanban View, Global Search, Employee Loan & Customer Feedback
# ERPNext - Stock Opening Balance
# ERPNext for Distributors
# Webinar on Frappe Portals
# ERPNext - Accounts Opening Balance
# Webinar on Frappe Framework
# ERPNext Customization
# ERPNext - Engineer-to-Order
# ERPNext - Managing Taxes
# ERPNext - Chart of Accounts Builder
# ERPNext - Chart of Accounts
# ERPNext - Shopify Integration
# ERPNext - HR module
# ERPNext for Schools
# ERPNext for Retailers
# ERPNext - Customer Relationship Management (CRM)
# ERPNext for Services Business
# ERPNext - Customers and Suppliers
# ERPNext - Managing Items and prices
# Kanhaiya Kale - Making ERPNext a Success
# Rohit Sharma - Challenges of Successful ERP Implementation
# Antonious Tara - Building ERPNext Capabilities
# Jay Ram - Enhancing the Manufacturing Module
# Revant Nandgaokar - Extending ERPNext
# Hisham Farid - ERPNext implementation in a company having 20,000 employees
# Tony Ta - Building Successful Client Relationships
# Eric B. Delisle - Taking ERPNext Forward
# Vivek Digambernath - Building a career around ERPNext
# Aditya Duggal - Deep ERPNext Customizations at Rohit Industries Group
# Dominik Ottenbreit - How Community can Contribute in ERPNext
# Andrew Togniolo - Extending ERPNext for the Enterprise
# Basawaraj Savalagi - ERPNext Implementation at Selco India, a Social Enterprise
# Saurabh Palande - Portal for Service Providers and Bench Central
# Shreyas Patil - Best Practices for Self hosting ERPNext
# Neil Lasrado - ERPNext for Schools
# Faris Ansari - ERPNext Version 7 Features
# Rohit Waghchaure - ERPNext Version 7 Features
# Umair Sayyed - ERPNext Version 7 Features
# Kanchan Chauhan - ERPNext Community Statistics
# Nabin Hait - ERPNext Community Activity Future Roadmap
# ERPNext Conf 2016: Rushabh Mehta - From the Cathedral to the Bazaar
# ERPNext - Bulk Update
# ERPNext - Importing data from spreadsheet file
# ERPNext - Request for Quotation
# ERPNext - Budgeting
# ERPNext Education - Setup Wizard
# ERPNext - Fixed Asset Management
# ERPNext - Salary Structure
# ERPNext Version 7 Release Presentation
# ERPNext - PayPal Integration
# Hello from ERPNext for University of Strasbourgh
# ERPNext Gource
# Session 4: Scripting DocTypes - I
# Session 10: Web Views
# Session 9: Testing and Debugging
# Session 8: Pushing to Git and Docs
# Session 7: Connecting Using Hooks
# Session 6: Views and Navigation
# Session 5: Scripting DocTypes   II
# Session 3: Making DocTypes   II
# Session 2: Making DocTypes   I
# Session 1: Creating an App
# ERPNext - Report Builder
# ERPNext - Shopping Cart
# ERPNext - Drop Shipping
# ERPNext - Publish Items on Website
# ERPNext Installation on AWS
# Setting up another ERPNext site and installing ERPNext demo
# ZFS Admin screencast
# ERPNext - File Manager
# New Indicatrans - Made with ERPNext
# Pratik Vyas - Frappe Async and Bench Admin
# Saurabh Palande - File Manager and Shopify Integration
# Neha - How ERPNext has helped Boacasa
# Dominik Ottenbreit - Using ERPNext and how you can contribute
# Neil Lasrado - ERP for Non-Profit and Education
# Anand Doshi - Let's make a webapp
# Nabin Hait - New features in ERPNext
# Umair Sayyed - Customers in different countries and industries
# Rushabh Mehta - ERPNext Community Stats
# Sukh Dugal - Humans and Design
# Kovid Goyal - Sustaining a Large Open Source Project
# Jordan Hubbard - How to Monetize Open Source
# Rushabh Mehta - Introduction, ERPNext Foundation
# ERPNext - Item Variant
# ERPNext - Quality Inspection
# ERPNext - Product Bundle
# ERPNext - Batchwise Inventory
# ERPNext - Newsletter
# ERPNext - Managing Serialized Inventory
# ERPNext - Subcontracting
# ERPNext - Stock Entry
# ERPNext - Point of Sale
# ERPNext - Expense Claim Management
# ERPNext - Employee
# ERPNext - Leave Management
# ERPNext - Field Customization
# ERPNext - Workflow
# ERPNext - Printing and Branding
# ERPNext - Setting up Email
# ERPNext Version 5 Teaser
# Snippets from ERPNext Users from across the Globe
# Umair Sayyed on how ERPNext uses ERPNext
# Tarun Gupta of Neural Integrated System shares why he moved to ERPNext from Sage
# Sonal Ramnathkar of Eudora Enterprises shares why ERPNext worked at her Manufacturing Startup
# Prashant Thakkar of Mukund Hardware shares his ERPNext Implementation Story
# Nabin Hait on the History of ERPNext
# Mahesh Malani on implementing ERPNext for his business
# Deepak Gupta on ERPNext Implementation at Bullows Paint Equipment
# Anand Doshi on ERPNext Version 4
# Aditya Duggal on his ERPNext Journey
# ERPNext Conference 2014 Introduction - Rushabh Mehta
# ERPNext - Video testimonial

# %%
print(video)
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'v_-GpE4a8ikayqXBDX2PqMdaM3c', 'id': 'VVVuM2JWNWt4NzdIc1Z3dG5sQ2VFaV9BLjEzRjc5NENBMjAwNERDQUE=', 'snippet': {'publishedAt': '2014-08-25T07:05:28Z', 'channelId': 'UCn3bV5kx77HsVwtnlCeEi_A', 'title': 'ERPNext - Video testimonial', 'description': 'ERPNext is a web based ERP solution. This is the testimonial from one of our user in USA.\n\nhttps://erpnext.com', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iGdchhwQa9o/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/iGdchhwQa9o/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/iGdchhwQa9o/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/iGdchhwQa9o/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': 'ERPNext', 'playlistId': 'UUn3bV5kx77HsVwtnlCeEi_A', 'position': 317, 'resourceId': {'kind': 'youtube#video', 'videoId': 'iGdchhwQa9o'}}}
